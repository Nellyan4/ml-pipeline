# %% [markdown]
# ## Data Cleaning and Cross Validation

# %% [markdown]
# In this NB we walk thru cleaning the Titanic data set available from
# [Kaggle](https://www.kaggle.com/c/titanic).  There are two files in this data set: `train.csv` and `test.csv`. Note that observations in the `train.csv` file have a `Survived` column whereas observations in `test.csv` do no. The goal of the Kaggle competition is to use the observations in `train.csv` to develope a classifier which will be used to predict whether a person in the `test.csv` data set survived the Titanic or not.  We will use this data set to demonstrate how to (i) set up an ml pipeline for preprocessing the data and (ii) use cross validation to measure the performance of the classifier

# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# ### Dealing with missing (NaN) values

# %% [markdown]
# The Pandas idiosyncratic way of determining which observations have missing values is:

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Three general approaches to dealing with missing values.
# 1. Omit the observation all together
# 2. Omit just the column (variable) with the missing value
# 3. "Fill in" the missing value.  A process known as imputation

# %%
train[train.Embarked.isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# There isn't an easy way for us to determine where these two passengers Embarked.  So we can either drop this variable or drop the two observations.   Lets do the later.  We can drop these in two ways:

# %%
df = train[train.Embarked.notna()]
df.shape
# Out:
# (889, 12)

# %%
df = train.dropna(subset=['Embarked'])
df.shape
# Out:
# (889, 12)

# %% [markdown]
# Now, what about the `Age` and `Cabin` variables which also have NA values?  `Cabin` number doesn't seem to be a strong predictor, so lets omit that.  Lets impute the `Age` with the mean value.

# %%
features = 'Sex Embarked    Fare     Age'.split()
features
# Out:
# ['Sex', 'Embarked', 'Fare', 'Age']

# %%
X = df[features]
y = df.Survived

# %% [markdown]
# #### Imputation

# %%
X.Age.head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# Name: Age, dtype: float64

# %%
X.Age.isna().sum()
# Out:
# 177

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer()

# %%
imp.fit(X[['Age']])
# Out:
# SimpleImputer()

# %%
imp.transform(X[['Age']])[:20]
# Out:
# array([[22.       ],
#        [38.       ],
#        [26.       ],
#        [35.       ],
#        [35.       ],
#        [29.6420927],
#        [54.       ],
#        [ 2.       ],
#        [27.       ],
#        [14.       ],
#        [ 4.       ],
#        [58.       ],
#        [20.       ],
#        [39.       ],
#        [14.       ],
#        [55.       ],
#        [ 2.       ],
#        [29.6420927],
#        [31.       ],
#        [29.6420927]])

# %%
imp.fit_transform(X[['Age']]);

# %% [markdown]
# **Important:** Make sure you understand the difference between `.fit`, `.transform`, and `.fit_transform`

# %% [markdown]
# ### One Hot Encoding

# %% [markdown]
# Many ML algorithms require the feature matrix to be numeric.  This will require nominal variables to be encoded with One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

# %%
ohe = OneHotEncoder(sparse=False)  # false is just for illustration

# %%
ohe.fit_transform(X[['Embarked']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-522f2433543a> in <module>()
# ----> 1 ohe.fit_transform(X[['Embarked']])
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Baseline

# %%
df.Survived.value_counts(normalize=True)
# Out:
# 0    0.617548
# 1    0.382452
# Name: Survived, dtype: float64

# %% [markdown]
# ## Pipeline

# %%
from sklearn.compose import make_column_transformer

# %%
imp = SimpleImputer()
ohe = OneHotEncoder()

ct = make_column_transformer(
       (ohe, ['Sex', 'Embarked']),
       (imp, ['Age']),
       remainder = 'passthrough'
)

# %%
a = ct.fit_transform(X)
a[:5, : ]
# Out:
# array([[ 0.    ,  1.    ,  0.    ,  0.    ,  1.    , 22.    ,  7.25  ],
#        [ 1.    ,  0.    ,  1.    ,  0.    ,  0.    , 38.    , 71.2833],
#        [ 1.    ,  0.    ,  0.    ,  0.    ,  1.    , 26.    ,  7.925 ],
#        [ 1.    ,  0.    ,  0.    ,  0.    ,  1.    , 35.    , 53.1   ],
#        [ 0.    ,  1.    ,  0.    ,  0.    ,  1.    , 35.    ,  8.05  ]])

# %% [markdown]
# The above is the transformation of the below data frame

# %%
X.head(5)
# Out:
#       Sex Embarked     Fare   Age
# 0    male        S   7.2500  22.0
# 1  female        C  71.2833  38.0
# 2  female        S   7.9250  26.0
# 3  female        S  53.1000  35.0
# 4    male        S   8.0500  35.0

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.pipeline import make_pipeline

# %%
ct = make_column_transformer(
       (ohe, ['Sex', 'Embarked']),
       (imp, ['Age']),
       remainder = 'passthrough'
)

from sklearn.linear_model import LogisticRegression

lgr = LogisticRegression()

p1 = make_pipeline(ct, lgr)

X = df[features]
y = df.Survived


from sklearn.model_selection import cross_val_score

cross_val_score( p1, X , y, cv=5, scoring='accuracy').mean()
# Out:
# 0.7795404050022217

# %%
# !ls
# Out:
# sample_data  test.csv  train.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# MyDrive  Shareddrives

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  00-a5-rel-model-normalization-rubric-f21.xlsx
#  01-1-ds-s17-introduction.pptx
#  2017-madurai-readers-club-data-science.pptx
#  20190507_172647.jpg
#  20190507_172658.jpg
#  20190507_172709.jpg
#  373
#  582a677208ae138f1bf34cba.pdf
#  5-morning-rituals-that-help-me-win-the-day1.pdf
#  67262-f16-schedule-landscape.gdoc
#  67262-f19-syllabus.pdf
# '67475 Teams 2016.xlsx'
# '67475 Teams 2016.xlsx.gsheet'
#  784758362150.pdf
#  95885-project-2-s20.pdf
# '95885-s20-syllabus (1).pdf'
#  95885-s20-syllabus.pdf
#  a1-jaiswalshubham.xlsx.gsheet
# 'a1_load (1).sql'
#  a1_load.sql
# 'a2-assignment_johannas (3).Rmd'
#  a3-flight-connections-exercise.ipynb
#  a3-flight-connections-solution.ipynb
#  a3-gender-neutral-babynames-exercise.ipynb
#  a3-gender-neutral-babynames-solution.ipynb
#  a3-joins
# 'a3-visualization-critique-ds-s20 (1).pdf'
#  a3-visualization-critique-ds-s20.pdf
#  a4-charleyz.xlsx.gsheet
#  a5-convert-to-relational-model.docx
#  a5-recommender-systems-template.pdf
# 'a6-mapreduce-mrjob-ds-s20 (1).pdf'
#  a6-mapreduce-mrjob-ds-s20.pdf
# 'a7-pagerank-mrjob-and-spark (1).pdf'
#  a7-pagerank-mrjob-and-spark.pdf
# 'airbnb-draft 1.pdf'
#  all
# 'Anand Geometry.gsheet'
#  AnandSooriamurthi_Resume_Sep12_2021_v5.docx
#  Apache-Spark-The-Definitive-Guide-Excerpts-R1.pdf
#  Assessment.gform
#  babynames_load.sql
# 'Capstone Project USPS'
# 'cmt (1).csv'
#  cmt.csv
#  cmt.gsheet
#  CMUPreCollege_LiabilityForm.gdoc
#  CMUPreCollege_LiabilityForm.pdf
#  CMUQ_Effort_template_Raja_Nov2018.gdoc
# 'Colab Notebooks'
# 'College Admissions'
# 'Copy of 11-5-2018 raja 475.gslides'
# 'Copy of collaborative doc for alumni tracking.gdoc'
# 'Copy of DataModelingReview Session.gslides'
# 'Copy of GFA Advisory Board Agenda - 1 12 21 - Agenda - Final.gdoc'
# 'Copy of HCEF - Task List_9.15.15.xlsx'
# 'Copy of HCEF - Task List_9.15.15.xlsx.gsheet'
# 'Copy of Normalization-sraja.gsheet'
# 'Copy of T11 - Iflix Customer Analysis.gslides'
# 'Copy of Terrorism and Human Freedom.gslides'
# 'CV Alejandro Rodriguez Eng.pages'
#  cv-tcm.pdf
#  cv-tcm.pdf.gdoc
#  dept
#  DSC00127-arnav.jpg
#  DSC00128-arnav.jpg
#  DSC07249-arnav.jpg
#  DSC07251-arnav.jpg
#  DynamoFLYERWinter2016SideBySide.pdf
#  e1-p1.pdf
#  e1-p3-draft-key.docx
#  e1-p3-sec-2.pdf
#  e1-p3-sec-3.pdf
#  e2-v1.docx
#  Exercise03_HDFS.pdf
#  f20-885
#  f21-67262-master-lab-checkoff.gsheet
#  fisher.pdf
# 'flights-load (1).sql'
#  flights-load.sql
# 'f-p2-exam (1).pdf'
#  f-p2-exam.pdf
#  hadoop
# 'Hypothesis Matrix.xlsx'
#  IMG_3137.jpg
# 'Interview Schedule 5.docx'
# 'IS Student Info as of F20 Shared Data.gsheet'
# 'ITAM Orientation Schedule.docx'
# 'ITINERARY for Harris Kyriakou Wed Feb 10.gdoc'
# 'Kaggle Independent Study'
#  kids
# 'M16 95-568 A Data Management and Security - Course Evaluation - Raja Sooriamurthi.xlsx'
# 'M16 95-568 A Data Management and Security - Course Evaluation - Raja Sooriamurthi.xlsx.gsheet'
# 'Meghashyam essays Supplemental Part 2.gdoc'
# 'MoM 2016.docx'
# 'new house painting.gsheet'
# 'NFL Predictions.gdoc'
#  Notes
#  personal
# 'Petrucci Outdoor Creations 1548 shady ave.docx'
#  PhotoRoster-F21-67262-3.pdf
#  photos
#  photos.gslides
#  ppia-m21-taxi-tips-exercise.gsheet
#  ppia-m21-taxi-tips.gsheet
#  pub
#  qz03.pdf
#  qz11-sec3.pdf
#  qz12-s3.pdf
#  relationalmodel-5.pdf
#  renewal-2019
#  scratch
# 'Screen Shot 2016-04-13 at 10.54.38 AM.png'
#  Slides
#  Song-Sara-shsong-1-C.gsheet
# 'Song-Susan-sssong-3-L (1).gsheet'
#  Song-Susan-sssong-3-L.gsheet
#  sraja-Normalization-262-a.gsheet
#  sraja-Normalization-262-b.gsheet
# 'Su Dong Schedule.pdf'
#  teaching
# 'Three Paragraphs for Joe.gdoc'
#  time.gsheet
# 'Untitled document.gdoc'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'VTS - Alexis Braun.gsheet'
# 'VTS - Alexis Braun.xlsx'
#  vts.csv
#  WP_Top_5_Database_Security_Threats.pdf
# 'YesPlus Petition'

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
cd ..
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/  Shareddrives/

# %%
cd Shareddrives/
# Out:
# /content/drive/Shareddrives

# %%
ls
# Out:
# 'Jigsaw: Identifying toxicity and bias online'/
